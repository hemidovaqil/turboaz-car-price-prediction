# %% [markdown]
# <a href="https://colab.research.google.com/github/hemidovaqil/turboaz-car-price-prediction/blob/main/Splitting%20data%20into%20training%20and%20test%20sets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1. Splitting data into training and test sets
#
# We split the data into features X and the target variable y.
# 80% of the data is used to train the model, and 20% is used for testing.

# %%
import pandas as pd

df = pd.read_csv('/content/cars.csv', engine='python')
display(df.head())
# Out:
#                                    id_x                        car_rel_url_x  \
# 0  3c234145-d57a-4ad6-9448-d43810fc3392           /autos/8748840-hyundai-i30
# 1  c74ea36f-6be1-4de4-926d-e117197dcf00  /autos/8475807-lada-vaz-niva-travel
# 2  9cefceb0-024d-4581-a869-a3c2c68a9f95   /autos/8739686-toyota-land-cruiser
# 3  459cc337-fb63-48de-9694-41554923d311       /autos/8712597-hyundai-elantra
# 4  6c5ee8d8-1c6f-4fad-a694-957a4c43c25d          /autos/8674773-toyota-prius
#
#                  datetime_scrape                    name  price_x currency_x  \
# 0  2024-09-13 20:32:19.751157+00             Hyundai i30  15000.0        AZN
# 1  2024-09-13 20:32:19.751157+00  LADA (VAZ) Niva Travel  23700.0        AZN
# 2  2024-09-13 20:32:19.751157+00     Toyota Land Cruiser  35600.0          $
# 3  2024-09-13 20:32:19.751157+00         Hyundai Elantra  26700.0        AZN
# 4  2024-09-13 20:32:19.751157+00            Toyota Prius  10500.0        AZN
#
# ...

# %% [markdown]
# ### Conclusion
#
# The data is split into training and test sets using an 80/20 ratio. The split is performed prior to feature scaling and encoding to avoid data leakage.
